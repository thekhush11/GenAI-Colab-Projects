# %% [markdown]
# gan variants
#
# 1. dcgan(deep convolution gan)
# 2. conditional gan
# 3. cycle gan

# %%
#conditional gan

# %% [markdown]
# conditional gan
#
# special type of gan where you give extra information to both the generator and the discriminator so the generator learns to create outputs that match that condition.
#
#
# ---use
#
# image to image translation
#
# label control generation
#
# text to image
#
# ---workflow
#
# 1. data preparation
# 2. build generator
#
# -input
# 1. label imputs(1D)
#
# -label embedding
#
# --concat image + label embedding
#
# --layers
# 1. conv2D
# 2. relu
# 3. dropout
#
# --build flatten and dense layer
#
# -noise*label embedding
#
# -

# %% [markdown]
# Q.1. What is the difference between Discriminative and Genearative Models?
#
# Q.2. Explain the role of probablity distribution in generative models?
#
# Q.3. How text generative model different from image generative models?
#
# Q.4. What is the main challenges you faced with music generation model?
#
# Q.5. Can we use a Generative models for anamoly detection? If yes then How?
#
# Q.6. What is AutoEncoder?
#
# Q.7. Difference between VAN and Traditional Auto Encoder?
#
# Q.8. What is the main role of Encoder and Decoder in variational Auto Encoder?
#
# Q.9. What is latent space?
#
# Q.10. What is the limitation of Variational Auto Encoders compaired to GANs?
#
# Q.11. Explain the role of Generator and Discriminator in a GANs?
#
# Q.12. What is the objective function of a GANs?
#
# Q.13. How to you evalute the Quality of Image generated by GANs?
#
# Q.14. WHat is the difference between DCGAN, Conditional GAN and Cycle GAN?
#
# Q.15. What is the main purpose of Cycle GAN?
